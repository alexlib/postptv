# %%
from matplotlib import pyplot
import os, sys
# sys.path.insert(0,os.path.abspath('/Users/alex/Documents/OpenPTV/postptv/'))
from flowtracks.io import trajectories_ptvis
# %matplotlib inline

# %%
inName = './hristo-data/ptv_is.%d'
trajects = trajectories_ptvis(inName, traj_min_len=5) # the directory with the input files

# %%
pyplot.figure(figsize = (12, 10))

positions = [tr.pos() for tr in trajects]
for pos in positions:
	trajX = [pos[k][0] for k in range(len(pos))]
	trajY = [pos[k][1] for k in range(len(pos))]
	pyplot.plot(trajX, trajY, '.')

pyplot.legend()
pyplot.show()
# Out:
# /Users/alex/Library/Enthought/Canopy_32bit/User/lib/python2.7/site-packages/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %%
inName = './hristo-data/xuap.%d'
trajects = trajectories_ptvis(inName, traj_min_len=2, xuap=True, first=10000,last=10144) # the directory with the input files

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = pyplot.figure(figsize=(12,8))
ax = fig.add_subplot(1,1,1, projection='3d')
positions = [tr.pos() for tr in trajects]    
for pos in positions:
    trajX = [pos[k][0] for k in range(len(pos))]
    trajY = [pos[k][1] for k in range(len(pos))]
    trajZ = [pos[k][2] for k in range(len(pos))]
    ax.plot(trajX, trajY, trajZ)

# %%
trajects = trajectories_ptvis(inName, traj_min_len=5,xuap=True,first=10000,last=10010) # the directory with the input files
